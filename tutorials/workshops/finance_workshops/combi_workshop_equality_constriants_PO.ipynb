# %% [markdown]
# # Quantum Optimization Training - Part 2
# ## Dealing with Constraint Using Portfolio Optimization

# %% [markdown]
# In this workshop, we will solve the Portfolio Optimization problem using the Quantum Approximate Optimization Algorithm (QAOA), by **introducing how to add various types of constraints of the problem to the QAOA algorithm**.

# %% [markdown]
# ## Guidance for the Workshop:
# **The `# TODO` or `# Your code` is there for you to do yourself.**
# **The `# Solution start` and `# Solution end` are only for helping you. Please delete the `Solution` and try doing it yourself...**

# %% [markdown]
# ## Portfolio Optimization with the Quantum Approximate Optimization Algorithm (QAOA)
# ### Introduction
# Portfolio optimization is the process of allocating a portfolio of financial assets optimally, according to some predetermined goal. Usually, the goal is to maximize the potential return while minimizing the financial risk of the portfolio. One can express this problem as a combinatorial optimization problem like many other real-world problems. In this demo, we'll show how the Quantum Approximate Optimization Algorithm (QAOA) can be employed on the Classiq platform to solve the problem of portfolio optimization.
# ### Modeling the Portfolio Optimization Problem
# As a first step, we have to model the problem mathematically. We will use a simple yet powerful model, which captures the essence of portfolio optimization:
# - A portfolio is built from a pool of $n$ financial assets, each asset labeled $i \in \{1,\ldots,n\}$.
# - Every asset's return is a random variable, with expected value $\mu_i$ and variance $\Sigma_i$ (modeling the financial risk involved in the asset).
# - Every two assets $i \neq j$ have covariance $\Sigma_{ij}$ (modeling market correlation between assets).
# - Every asset $i$ has a weight $w_i \in D_i = \{0,\ldots,b_i\}$ in the portfolio, with $b_i$ defined as the budget for asset $i$ (modeling the maximum allowed weight of the asset).
# - The return vector $\mu$, the covariance matrix $\Sigma$ and the weight vector $w$ are defined naturally from the above (with the domain $D = D_1 \times D_2 \times \ldots \times D_n$ for $w$).
#
# With the above definitions, the total expected return of the portfolio is $\mu^T w$ and the total risk is $w^T \Sigma w$. We'll use a simple difference of the two as our cost function, with the additional constraint that the total sum of assets does not exceed a predefined budget $B$. We note that there are many other possibilities for defining a cost function (e.g. add a scaling factor to the risk/return or even some non-linear relation). For reasons of simplicity we select the model below, and we assume all constants and variables are dimensionless.
# Thus, the problem is, given the constant inputs $\mu, \Sigma, D, B$, to find optimal variable $w$ as follows:
# $$
# \min_{w \in D}  w^T \Sigma w - \mu^T w,
# $$
# subject to $\Sigma_{i} w_i \leq B$.
# The case presented above is called integer portfolio optimization, since the domains $D_i$ are over the (positive) integers.
# Another variation of this problem defines weights over binary domains, and will not be discussed here.

# %%
import math

# import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize

from classiq import *

# %% [markdown]
# ### First We Will Solve the Problem Without Adding Constraint.
# Just:
# $$
# \min_{w \in D}  w^T \Sigma w - \mu^T w
# $$
#
# ### Then, We Will Add Equality Constraint:
#
# $$
# \min_{w \in D}  w^T \Sigma w - \mu^T w
# $$
# subject to:
# $$\Sigma_{i} w_i == B$$
#
# ### Finaly, We Will Add Inequality Constraints:
#
# $$
# \min_{w \in D}  w^T \Sigma w - \mu^T w,
# $$
# subject to:
# $$\Sigma_{i} w_i \leq B$$

# %% [markdown]
# ## The Portfolio Optimization Problem Parameters
# First we define the parameters of the optimization problem, which include the expected return vector, the covariance matrix, the total budget and the asset-specific budgets.

# %%
returns = np.array([3, 4, -1])
# fmt: off
covariances = np.array(
    [
        [ 0.9,  0.5, -0.7],
        [ 0.5,  0.9, -0.2],
        [-0.7, -0.2,  0.9],
    ]
)
# fmt: on
total_budget = 6

# %% [markdown]
# ## Defining the Variables

# %%
num_assets = 3

num_qubits_per_asset = 2  # Defines the possible values of choosing each asset.


class PortfolioOptimizationVars(QStruct):
    a: QArray[QNum[num_qubits_per_asset], num_assets]

# %% [markdown]
# ### Define the Expected Return
# Define a function that describes $\mu^T w$ where $\mu$ is the `return` vector.

# %%
def expected_return_cost(
    returns: np.ndarray, w_array: PortfolioOptimizationVars
) -> float:
    # Your code here

    # Solution start
    return sum(returns[i] * w_array.a[i] for i in range(len(returns)))
    # Solution end

# %% [markdown]
# ### Define the Risk Term
# Define a function that describes the risk term in the objective function $w^T \Sigma w$ where $\Sigma$ is the `covariances` matrix.

# %%
def risk_cost(covariances: np.ndarray, w_array: PortfolioOptimizationVars) -> float:
    # Your code here

    # hint:
    # risk_term =  sum(
    #     ... * sum(... for j in range(covariances.shape[0])) for i in range(covariances.shape[0])
    # )

    # Solution start
    risk_term = sum(
        w_array.a[i]
        * sum(w_array.a[j] * covariances[i][j] for j in range(covariances.shape[0]))
        for i in range(covariances.shape[0])
    )
    # Solution end
    return risk_term

# %% [markdown]
# ### Define the Entire Portfolio Optimization Objective Function
#
# Combine the risk term and the expected return functions.
# There a a term called return coefficient `return_coeff` that defines how much you prefer certainly over return. Higher values is more risky but can be more profitable.
# Later try changing it to see how the result changes.

# %%
return_coeff = 1.5


def objective_portfolio(
    w_array: PortfolioOptimizationVars,
    returns: np.ndarray,
    covariances: np.ndarray,
    return_coeff: float,
) -> float:
    # Your code here

    # Solution start

    return risk_cost(covariances, w_array) - return_coeff * expected_return_cost(
        returns, w_array
    )
    # Solution end

# %% [markdown]
# ## Build the QAOA Circuit

# %%
@qfunc
def mixer_layer(beta: CReal, qba: QArray):
    # Your code here

    # Solution start
    apply_to_all(lambda q: RX(beta, q), qba)
    # Solution end

# %%
NUM_LAYERS = 4


@qfunc
def main(
    params: CArray[CReal, 2 * NUM_LAYERS], w_array: Output[PortfolioOptimizationVars]
) -> None:
    # Your code here

    # Allocating the qubits
    allocate(w_array)

    # Build the QAOA circuit similarly to the maxcut

    # Solution start
    hadamard_transform(w_array)

    repeat(
        count=int(params.len / 2),
        iteration=lambda i: (
            phase(
                objective_portfolio(w_array, returns, covariances, return_coeff),
                params[2 * i],
            ),
            mixer_layer(params[2 * i + 1], w_array),
        ),
    )
    # Solution end

# %% [markdown]
# ## Synthesizing and Visualizing

# %%
qprog = synthesize(main)
show(qprog)
# Out:
# Quantum program link: https://platform.classiq.io/circuit/3IjNqEV5SemaDuD0gxjf5DIV44e
# https://platform.classiq.io/circuit/3IjNqEV5SemaDuD0gxjf5DIV44e?login=True&version=22

# %% [markdown]
# ## Execution and Post Processing
#
# For the hybrid execution, we use `ExecutionSession`, which can evaluate the circuit in multiple methods, such as sampling the circuit, giving specific values for the parameters, and evaluating to a specific Hamiltonian, which is very common in chemical applications.
#
# In QAOA, we will use the `estimate_cost` method, which samples the cost function and returns their average cost from all measurements. That helps to optimize easily.

# %%
NUM_SHOTS = 1000

es = ExecutionSession(qprog, num_shots=NUM_SHOTS)


# Build `initial_params` list of np.array type.
# The gamma values should start from 0 and, in each layer, should approach closer to 1 linearly
# The beta values should start from 1 and in each layer, should approach closer to 0 linearly
# Then unify it to one list so scipy minimize can digest it.
# Your code here


# Solution start
def initial_qaoa_params(NUM_LAYERS) -> np.ndarray:
    initial_gammas = math.pi * np.linspace(0, 1, NUM_LAYERS)
    initial_betas = math.pi * np.linspace(1, 0, NUM_LAYERS)

    initial_params = []

    for i in range(NUM_LAYERS):
        initial_params.append(initial_gammas[i])
        initial_params.append(initial_betas[i])

    return np.array(initial_params)


# Solution end

initial_params = initial_qaoa_params(NUM_LAYERS)

# %% [markdown]
# ## Define a Callback Function to Track the Optimization

# %%
# Record the steps of the optimization
intermediate_params = []
objective_values = []


# Define the callback function to store the intermediate steps
def callback(xk):
    intermediate_params.append(xk)

# %% [markdown]
# ## Define the Objective Function

# %%
# Your code with hints in the comments:

# cost_func = lambda state: objective_portfolio(
#     w_array = ...,
#     returns = ...,
#     covariances = ...,
#     return_coeff= ...
# )
# def estimate_cost_func(params: np.ndarray) -> float:
#     objective_value = es.estimate_cost(
#         cost_func = ...,
#         parameters = {"params": params.tolist()}
#     )
#     # Your code here
#     # Save the result for convergence graph
#
#     return objective_value


# Solution start
cost_func = lambda state: objective_portfolio(
    w_array=state["w_array"],
    returns=returns,
    covariances=covariances,
    return_coeff=return_coeff,
)


def estimate_cost_func(params: np.ndarray) -> float:
    objective_value = es.estimate_cost(
        cost_func=cost_func, parameters={"params": params.tolist()}
    )
    objective_values.append(objective_value)
    return objective_value


# Solution end

# %% [markdown]
# ## Optimize

# %%
# Your code with hints in the comments:

# optimization_res = minimize(
#     fun = ...,
#     x0=...,
#     method="COBYLA",
#     callback=...,
#     options={"maxiter": 10},
# )

# Solution start
optimization_res = minimize(
    fun=estimate_cost_func,
    x0=initial_params,
    method="COBYLA",
    callback=callback,
    options={"maxiter": 30},
)
# Solution end

# %% [markdown]
# ## Look at the Results

# %%
res = es.sample({"params": optimization_res.x.tolist()})

print(f"Optimized parameters: {optimization_res.x.tolist()}")

sorted_counts = sorted(
    res.parsed_counts,
    key=lambda pc: objective_portfolio(
        pc.state["w_array"],
        returns=returns,
        covariances=covariances,
        return_coeff=return_coeff,
    ),
)

for sampled in sorted_counts:
    w_sample = sampled.state["w_array"]
    print(
        f"solution={w_sample} probability={sampled.shots/NUM_SHOTS} "
        f"cost={objective_portfolio(w_array=w_sample,returns = returns, covariances = covariances, return_coeff= return_coeff)}"
    )
# Out:
# Optimized parameters: [-0.566381801809804, 3.114438048071574, 0.3741917584727741, 1.6886396698761594, 1.5982613850247316, 2.200534928670613, 3.1317169261322864, -0.14611144138850377]
# solution={'a': [3, 2, 2]} probability=0.028 cost=-11.2
# solution={'a': [2, 2, 1]} probability=0.218 cost=-11.000000000000002
# solution={'a': [2, 3, 1]} probability=0.055 cost=-10.9
# solution={'a': [2, 3, 2]} probability=0.029 cost=-10.700000000000001
# solution={'a': [1, 3, 1]} probability=0.007 cost=-10.700000000000001
# solution={'a': [3, 3, 2]} probability=0.009 cost=-10.5
# solution={'a': [1, 3, 0]} probability=0.005 cost=-10.499999999999998
# solution={'a': [3, 2, 1]} probability=0.13 cost=-10.4
# solution={'a': [2, 2, 2]} probability=0.047 cost=-10.4
# solution={'a': [3, 2, 3]} probability=0.055 cost=-10.199999999999998
# solution={'a': [1, 2, 0]} probability=0.004 cost=-10.0
# solution={'a': [3, 3, 3]} probability=0.006 cost=-9.899999999999999
# solution={'a': [0, 3, 0]} probability=0.002 cost=-9.899999999999999
# solution={'a': [2, 2, 0]} probability=0.041 cost=-9.8
# solution={'a': [1, 2, 1]} probability=0.012 cost=-9.8
# solution={'a': [3, 1, 1]} probability=0.003 cost=-9.700000000000001
# solution={'a': [3, 3, 1]} probability=0.001 cost=-9.3
# solution={'a': [2, 3, 0]} probability=0.01 cost=-9.299999999999997
# solution={'a': [1, 3, 2]} probability=0.002 cost=-9.1
# solution={'a': [2, 3, 3]} probability=0.006 cost=-8.7
# solution={'a': [0, 3, 1]} probability=0.003 cost=-8.7
# solution={'a': [0, 2, 0]} probability=0.008 cost=-8.4
# solution={'a': [2, 2, 3]} probability=0.039 cost=-8.0
# solution={'a': [1, 2, 2]} probability=0.006 cost=-7.800000000000001
# solution={'a': [3, 2, 0]} probability=0.028 cost=-7.799999999999997
# solution={'a': [3, 1, 0]} probability=0.004 cost=-7.499999999999998
# solution={'a': [3, 0, 1]} probability=0.041 cost=-7.199999999999999
# solution={'a': [3, 0, 2]} probability=0.013 cost=-7.199999999999998
# solution={'a': [1, 1, 1]} probability=0.003 cost=-7.1
# solution={'a': [0, 2, 1]} probability=0.013 cost=-6.8
# solution={'a': [3, 3, 0]} probability=0.001 cost=-6.299999999999997
# solution={'a': [2, 0, 1]} probability=0.027 cost=-5.8
# solution={'a': [1, 3, 3]} probability=0.005 cost=-5.699999999999999
# solution={'a': [0, 3, 2]} probability=0.003 cost=-5.699999999999999
# solution={'a': [2, 1, 3]} probability=0.002 cost=-5.499999999999999
# solution={'a': [2, 0, 0]} probability=0.007 cost=-5.4
# solution={'a': [3, 0, 0]} probability=0.015 cost=-5.399999999999999
# solution={'a': [3, 0, 3]} probability=0.008 cost=-5.399999999999997
# solution={'a': [2, 0, 2]} probability=0.009 cost=-4.3999999999999995
# solution={'a': [1, 2, 3]} probability=0.002 cost=-4.0
# solution={'a': [1, 0, 0]} probability=0.001 cost=-3.6
# solution={'a': [0, 2, 2]} probability=0.003 cost=-3.4000000000000004
# solution={'a': [0, 1, 1]} probability=0.002 cost=-3.1
# solution={'a': [1, 0, 1]} probability=0.001 cost=-2.5999999999999996
# solution={'a': [2, 0, 3]} probability=0.011 cost=-1.1999999999999984
# solution={'a': [0, 3, 3]} probability=0.032 cost=-0.8999999999999986
# solution={'a': [1, 1, 3]} probability=0.001 cost=-0.5
# solution={'a': [0, 0, 0]} probability=0.007 cost=0.0
# solution={'a': [1, 0, 2]} probability=0.004 cost=0.20000000000000018
# solution={'a': [0, 2, 3]} probability=0.008 cost=1.8000000000000007
# solution={'a': [0, 0, 1]} probability=0.018 cost=2.4
# solution={'a': [1, 0, 3]} probability=0.002 cost=4.800000000000001
# solution={'a': [0, 0, 2]} probability=0.003 cost=6.6

# %% [markdown]
# ## Convergence Graph

# %%
# plt.plot(objective_values)
# plt.xlabel("Iteration")
# plt.ylabel("Objective Value")
# plt.title("Optimization Progress")

# %% [markdown]
# ## The Entire Solution

# %%
import math
from typing import List

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from scipy.optimize import minimize

from classiq import *

NUM_LAYERS = 3

returns = np.array([3, 4, -1])
# fmt: off
covariances = np.array(
    [
        [ 0.9,  0.5, -0.7],
        [ 0.5,  0.9, -0.2],
        [-0.7, -0.2,  0.9],
    ]
)
# fmt: on
total_budget = 6
specific_budgets = 3

return_coeff = 1.7

num_assets = 3

num_qubits_per_asset = 2

# start with integer variables


class PortfolioOptimizationVars(QStruct):
    a: QArray[QNum[num_qubits_per_asset], num_assets]


def expected_return_cost(
    returns: np.ndarray, w_array: PortfolioOptimizationVars
) -> float:
    return sum(returns[i] * w_array.a[i] for i in range(len(returns)))


def risk_cost(covariances: np.ndarray, w_array: PortfolioOptimizationVars) -> float:
    risk_term = sum(
        w_array.a[i]
        * sum(w_array.a[j] * covariances[i][j] for j in range(covariances.shape[0]))
        for i in range(covariances.shape[0])
    )
    return risk_term


def objective_portfolio(
    w_array: PortfolioOptimizationVars,
    returns: np.ndarray,
    covariances: np.ndarray,
    return_coeff: float,
) -> float:
    return risk_cost(covariances, w_array) - return_coeff * expected_return_cost(
        returns, w_array
    )


@qfunc
def mixer_layer(beta: CReal, qba: QArray):
    apply_to_all(lambda q: RX(beta, q), qba)


@qfunc
def main(
    params: CArray[CReal, 2 * NUM_LAYERS], w_array: Output[PortfolioOptimizationVars]
) -> None:

    allocate(w_array)

    hadamard_transform(w_array)

    repeat(
        count=int(params.len / 2),
        iteration=lambda i: (
            phase(
                objective_portfolio(w_array, returns, covariances, return_coeff),
                params[2 * i],
            ),
            mixer_layer(params[2 * i + 1], w_array),
        ),
    )


qprog = synthesize(main)
show(qprog)


NUM_SHOTS = 1000

es = ExecutionSession(qprog, num_shots=NUM_SHOTS)


def initial_qaoa_params(NUM_LAYERS) -> np.ndarray:
    initial_gammas = math.pi * np.linspace(0, 1, NUM_LAYERS)
    initial_betas = math.pi * np.linspace(1, 0, NUM_LAYERS)

    initial_params = []

    for i in range(NUM_LAYERS):
        initial_params.append(initial_gammas[i])
        initial_params.append(initial_betas[i])

    return np.array(initial_params)


initial_params = initial_qaoa_params(NUM_LAYERS)

# Record the steps of the optimization
intermediate_params = []
objective_values = []


# Define the callback function to store the intermediate steps
def callback(xk):
    intermediate_params.append(xk)


cost_func = lambda state: objective_portfolio(
    w_array=state["w_array"],
    returns=returns,
    covariances=covariances,
    return_coeff=return_coeff,
)


def estimate_cost_func(params: np.ndarray) -> float:
    objective_value = es.estimate_cost(
        cost_func=cost_func, parameters={"params": params.tolist()}
    )
    objective_values.append(objective_value)
    return objective_value


optimization_res = minimize(
    fun=estimate_cost_func,
    x0=initial_params,
    method="COBYLA",
    callback=callback,
    options={"maxiter": 10},
)

res = es.sample({"params": optimization_res.x.tolist()})

print(f"Optimized parameters: {optimization_res.x.tolist()}")

sorted_counts = sorted(
    res.parsed_counts,
    key=lambda pc: objective_portfolio(
        pc.state["w_array"],
        returns=returns,
        covariances=covariances,
        return_coeff=return_coeff,
    ),
)

for sampled in sorted_counts:
    w_sample = sampled.state["w_array"]
    print(
        f"solution={w_sample} probability={sampled.shots/NUM_SHOTS} "
        f"cost={objective_portfolio(w_array=w_sample,returns = returns, covariances = covariances, return_coeff= return_coeff)}"
    )

plt.plot(objective_values)
plt.xlabel("Iteration")
plt.ylabel("Objective Value")
plt.title("Optimization Progress")
# Out:
# Quantum program link: https://platform.classiq.io/circuit/3IjO421ZHIdt5qxOlfdKSCySknf
# https://platform.classiq.io/circuit/3IjO421ZHIdt5qxOlfdKSCySknf?login=True&version=22
# Optimized parameters: [1.117679216548696, 4.141592653589793, 1.5707963267948966, 1.6129460835259282, 3.141592653589793, 1.0]
# solution={'a': [2, 3, 1]} probability=0.012 cost=-14.299999999999999
# solution={'a': [3, 3, 2]} probability=0.007 cost=-14.299999999999997
# solution={'a': [3, 2, 2]} probability=0.023 cost=-14.2
# solution={'a': [2, 3, 2]} probability=0.001 cost=-13.9
# solution={'a': [3, 2, 1]} probability=0.032 cost=-13.6
# solution={'a': [2, 2, 1]} probability=0.031 cost=-13.6
# solution={'a': [1, 3, 1]} probability=0.006 cost=-13.500000000000002
# solution={'a': [1, 3, 0]} probability=0.011 cost=-13.499999999999998
# solution={'a': [3, 3, 3]} probability=0.068 cost=-13.499999999999996
# solution={'a': [3, 3, 1]} probability=0.007 cost=-13.3
# solution={'a': [3, 2, 3]} probability=0.02 cost=-12.999999999999998
# solution={'a': [2, 3, 0]} probability=0.021 cost=-12.899999999999995
# solution={'a': [2, 2, 2]} probability=0.006 cost=-12.799999999999999
# solution={'a': [2, 2, 0]} probability=0.011 cost=-12.600000000000001
# solution={'a': [3, 1, 2]} probability=0.022 cost=-12.299999999999999
# solution={'a': [0, 3, 0]} probability=0.003 cost=-12.299999999999997
# solution={'a': [3, 1, 1]} probability=0.031 cost=-12.1
# solution={'a': [1, 2, 1]} probability=0.024 cost=-11.8
# solution={'a': [2, 3, 3]} probability=0.004 cost=-11.7
# solution={'a': [1, 3, 2]} probability=0.022 cost=-11.699999999999998
# solution={'a': [3, 2, 0]} probability=0.008 cost=-11.199999999999996
# solution={'a': [0, 3, 1]} probability=0.02 cost=-10.899999999999999
# solution={'a': [2, 1, 0]} probability=0.017 cost=-10.5
# solution={'a': [3, 3, 0]} probability=0.005 cost=-10.499999999999993
# solution={'a': [2, 2, 3]} probability=0.034 cost=-10.2
# solution={'a': [3, 1, 0]} probability=0.004 cost=-10.099999999999996
# solution={'a': [0, 2, 0]} probability=0.012 cost=-10.0
# solution={'a': [2, 1, 2]} probability=0.003 cost=-9.899999999999999
# solution={'a': [1, 2, 2]} probability=0.006 cost=-9.6
# solution={'a': [1, 1, 0]} probability=0.016 cost=-9.100000000000001
# solution={'a': [3, 0, 1]} probability=0.108 cost=-8.799999999999999
# solution={'a': [3, 0, 2]} probability=0.002 cost=-8.599999999999998
# solution={'a': [1, 1, 1]} probability=0.025 cost=-8.299999999999999
# solution={'a': [0, 2, 1]} probability=0.005 cost=-8.2
# solution={'a': [1, 3, 3]} probability=0.014 cost=-8.099999999999998
# solution={'a': [0, 3, 2]} probability=0.005 cost=-7.699999999999999
# solution={'a': [3, 0, 0]} probability=0.008 cost=-7.1999999999999975
# solution={'a': [2, 1, 3]} probability=0.047 cost=-6.8999999999999995
# solution={'a': [2, 0, 1]} probability=0.015 cost=-6.8
# solution={'a': [2, 0, 0]} probability=0.019 cost=-6.6
# solution={'a': [0, 1, 0]} probability=0.031 cost=-5.8999999999999995
# solution={'a': [1, 1, 2]} probability=0.012 cost=-5.699999999999999
# solution={'a': [1, 2, 3]} probability=0.022 cost=-5.6
# solution={'a': [2, 0, 2]} probability=0.003 cost=-5.199999999999999
# solution={'a': [0, 2, 2]} probability=0.016 cost=-4.6
# solution={'a': [1, 0, 0]} probability=0.022 cost=-4.199999999999999
# solution={'a': [0, 1, 1]} probability=0.026 cost=-3.6999999999999997
# solution={'a': [1, 0, 1]} probability=0.017 cost=-3.0
# solution={'a': [0, 3, 3]} probability=0.003 cost=-2.6999999999999975
# solution={'a': [2, 0, 3]} probability=0.001 cost=-1.799999999999998
# solution={'a': [1, 1, 3]} probability=0.019 cost=-1.2999999999999998
# solution={'a': [0, 0, 0]} probability=0.011 cost=0.0
# solution={'a': [1, 0, 2]} probability=0.013 cost=2.220446049250313e-16
# solution={'a': [0, 1, 2]} probability=0.004 cost=0.30000000000000027
# solution={'a': [0, 2, 3]} probability=0.024 cost=0.8000000000000007
# solution={'a': [0, 0, 1]} probability=0.026 cost=2.6
# solution={'a': [1, 0, 3]} probability=0.009 cost=4.800000000000001
# solution={'a': [0, 1, 3]} probability=0.002 cost=6.1
# solution={'a': [0, 0, 2]} probability=0.003 cost=7.0
# solution={'a': [0, 0, 3]} probability=0.001 cost=13.200000000000001
# Text(0.5, 1.0, 'Optimization Progress')

# %% [markdown]
# ## Adding Equality Constraint

# %% [markdown]
# The method to deal with equality constraint, namely:
#
# $$
# \min_{w \in D}  w^T \Sigma w - \mu^T w
# $$
# subject to:
# $$\Sigma_{i} w_i == B$$
#
# is to add a penalty term to lead us to the set of valid solutions. To do so, we will change the objective function as follows:
#
# $$
# \min_{w \in D}  w^T \Sigma w - \mu^T w + P * (\Sigma_{i} w_i - B)^2
# $$
#
# Where $P$ is the penalty value you need to define.

# %% [markdown]
# ## Define the Objective Value with a Penalty Term

# %%
PENALTY = 2.0


def objective_portfolio_equality(
    w_array: PortfolioOptimizationVars,
    returns: np.ndarray,
    covariances: np.ndarray,
    return_coeff: float,
) -> float:
    # Your code here

    # Solution start

    return (
        risk_cost(covariances, w_array)
        - return_coeff * expected_return_cost(returns, w_array)
        + Penalty * (sum(w_array.a[i] for i in range(len(returns))) - total_budget) ** 2
    )
    # Solution end

# %% [markdown]
# ### Repeat the Whole Process All Over Again with `objective_portfolio_equality`

# %% [markdown]
# ## Solution

# %%
import math
from typing import List

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from scipy.optimize import minimize

from classiq import *

NUM_LAYERS = 3

returns = np.array([3, 4, -1])
# fmt: off
covariances = np.array(
    [
        [ 0.9,  0.5, -0.7],
        [ 0.5,  0.9, -0.2],
        [-0.7, -0.2,  0.9],
    ]
)
# fmt: on
total_budget = 6
specific_budgets = 3

return_coeff = 10.0

num_assets = 3

num_qubits_per_asset = 2

Penalty = 2.0

# start with integer variables


class PortfolioOptimizationVars(QStruct):
    a: QArray[QNum[num_qubits_per_asset], num_assets]


def expected_return_cost(
    returns: np.ndarray, w_array: PortfolioOptimizationVars
) -> float:
    return sum(returns[i] * w_array.a[i] for i in range(len(returns)))


def risk_cost(covariances: np.ndarray, w_array: PortfolioOptimizationVars) -> float:
    risk_term = sum(
        w_array.a[i]
        * sum(w_array.a[j] * covariances[i][j] for j in range(covariances.shape[0]))
        for i in range(covariances.shape[0])
    )
    return risk_term


def objective_portfolio_equality(
    w_array: PortfolioOptimizationVars,
    returns: np.ndarray,
    covariances: np.ndarray,
    return_coeff: float,
) -> float:
    return (
        risk_cost(covariances, w_array)
        - return_coeff * expected_return_cost(returns, w_array)
        + Penalty * (sum(w_array.a[i] for i in range(len(returns))) - total_budget) ** 2
    )


@qfunc
def mixer_layer(beta: CReal, qba: QArray):
    apply_to_all(lambda q: RX(beta, q), qba)


@qfunc
def main(
    params: CArray[CReal, 2 * NUM_LAYERS], w_array: Output[PortfolioOptimizationVars]
) -> None:
    allocate(w_array)

    hadamard_transform(w_array)

    repeat(
        count=int(params.len / 2),
        iteration=lambda i: (
            phase(
                objective_portfolio_equality(
                    w_array, returns, covariances, return_coeff
                ),
                params[2 * i],
            ),
            mixer_layer(params[2 * i + 1], w_array),
        ),
    )


qprog = synthesize(main)
show(qprog)


NUM_SHOTS = 1000

es = ExecutionSession(qprog, num_shots=NUM_SHOTS)


def initial_qaoa_params(NUM_LAYERS) -> np.ndarray:
    initial_gammas = math.pi * np.linspace(0, 1, NUM_LAYERS)
    initial_betas = math.pi * np.linspace(1, 0, NUM_LAYERS)

    initial_params = []

    for i in range(NUM_LAYERS):
        initial_params.append(initial_gammas[i])
        initial_params.append(initial_betas[i])

    return np.array(initial_params)


initial_params = initial_qaoa_params(NUM_LAYERS)

# Record the steps of the optimization
intermediate_params = []
objective_values = []


# Define the callback function to store the intermediate steps
def callback(xk):
    intermediate_params.append(xk)


cost_func = lambda state: objective_portfolio_equality(
    state["w_array"],
    returns=returns,
    covariances=covariances,
    return_coeff=return_coeff,
)


def estimate_cost_func(params: np.ndarray) -> float:
    objective_value = es.estimate_cost(
        cost_func=cost_func, parameters={"params": params.tolist()}
    )
    objective_values.append(objective_value)
    return objective_value


optimization_res = minimize(
    estimate_cost_func,
    x0=initial_params,
    method="COBYLA",
    callback=callback,
    options={"maxiter": 40},
)

res = es.sample({"params": optimization_res.x.tolist()})

print(f"Optimized parameters: {optimization_res.x.tolist()}")

sorted_counts = sorted(
    res.parsed_counts,
    key=lambda pc: objective_portfolio_equality(
        pc.state["w_array"],
        returns=returns,
        covariances=covariances,
        return_coeff=return_coeff,
    ),
)

for sampled in sorted_counts:
    w = sampled.state["w_array"]
    print(
        f"solution={w} probability={sampled.shots/NUM_SHOTS} "
        f"cost={objective_portfolio_equality(w_array=w,returns = returns, covariances = covariances, return_coeff= return_coeff)}"
    )

plt.plot(objective_values)
plt.xlabel("Iteration")
plt.ylabel("Objective Value")
plt.title("Optimization Progress")
# Out:
# Quantum program link: https://platform.classiq.io/circuit/3IjOA3iXPbkvBAwItTUYlx3DJur
# https://platform.classiq.io/circuit/3IjOA3iXPbkvBAwItTUYlx3DJur?login=True&version=22
# Optimized parameters: [-0.24813068477250566, 4.314353370316032, 0.1013642294126746, 1.3943645292857378, 4.164324062851786, -0.07961402589021498]
# solution={'a': [3, 3, 0]} probability=0.009 cost=-184.8
# solution={'a': [3, 3, 1]} probability=0.019 cost=-177.3
# solution={'a': [3, 3, 2]} probability=0.03 cost=-164.0
# solution={'a': [2, 3, 0]} probability=0.049 cost=-160.3
# solution={'a': [2, 3, 1]} probability=0.007 cost=-155.4
# solution={'a': [3, 2, 0]} probability=0.04 cost=-150.3
# solution={'a': [3, 2, 1]} probability=0.081 cost=-146.4
# solution={'a': [3, 3, 3]} probability=0.024 cost=-144.9
# solution={'a': [2, 3, 2]} probability=0.031 cost=-144.7
# solution={'a': [1, 3, 0]} probability=0.006 cost=-130.0
# solution={'a': [2, 3, 3]} probability=0.02 cost=-128.2
# solution={'a': [1, 3, 1]} probability=0.03 cost=-127.69999999999999
# solution={'a': [3, 2, 3]} probability=0.033 cost=-121.19999999999999
# solution={'a': [2, 2, 0]} probability=0.004 cost=-120.80000000000001
# solution={'a': [1, 3, 2]} probability=0.003 cost=-119.6
# solution={'a': [2, 2, 1]} probability=0.017 cost=-119.5
# solution={'a': [2, 2, 2]} probability=0.026 cost=-112.4
# solution={'a': [3, 1, 0]} probability=0.009 cost=-110.0
# solution={'a': [3, 1, 1]} probability=0.004 cost=-109.7
# solution={'a': [1, 3, 3]} probability=0.007 cost=-105.7
# solution={'a': [3, 1, 2]} probability=0.002 cost=-103.6
# solution={'a': [2, 2, 3]} probability=0.013 cost=-99.5
# solution={'a': [0, 3, 1]} probability=0.005 cost=-94.2
# solution={'a': [0, 3, 0]} probability=0.002 cost=-93.9
# solution={'a': [3, 1, 3]} probability=0.003 cost=-91.7
# solution={'a': [0, 3, 2]} probability=0.032 cost=-88.7
# solution={'a': [1, 2, 1]} probability=0.007 cost=-86.8
# solution={'a': [1, 2, 2]} probability=0.012 cost=-82.3
# solution={'a': [2, 1, 1]} probability=0.007 cost=-77.8
# solution={'a': [0, 3, 3]} probability=0.005 cost=-77.4
# solution={'a': [2, 1, 0]} probability=0.013 cost=-75.5
# solution={'a': [2, 1, 2]} probability=0.026 cost=-74.3
# solution={'a': [1, 2, 3]} probability=0.006 cost=-72.0
# solution={'a': [3, 0, 1]} probability=0.038 cost=-67.2
# solution={'a': [2, 1, 3]} probability=0.044 cost=-65.0
# solution={'a': [3, 0, 2]} probability=0.053 cost=-64.7
# solution={'a': [3, 0, 0]} probability=0.021 cost=-63.900000000000006
# solution={'a': [3, 0, 3]} probability=0.012 cost=-56.4
# solution={'a': [0, 2, 1]} probability=0.002 cost=-48.3
# solution={'a': [0, 2, 2]} probability=0.008 cost=-46.4
# solution={'a': [0, 2, 0]} probability=0.001 cost=-44.400000000000006
# solution={'a': [1, 1, 1]} probability=0.008 cost=-40.1
# solution={'a': [1, 1, 2]} probability=0.004 cost=-39.2
# solution={'a': [0, 2, 3]} probability=0.009 cost=-38.7
# solution={'a': [1, 1, 0]} probability=0.005 cost=-35.2
# solution={'a': [1, 1, 3]} probability=0.045 cost=-32.5
# solution={'a': [2, 0, 2]} probability=0.019 cost=-30.4
# solution={'a': [2, 0, 1]} probability=0.017 cost=-30.299999999999997
# solution={'a': [2, 0, 3]} probability=0.017 cost=-24.7
# solution={'a': [2, 0, 0]} probability=0.003 cost=-24.4
# solution={'a': [0, 1, 2]} probability=0.01 cost=1.6999999999999993
# solution={'a': [0, 1, 1]} probability=0.009 cost=3.3999999999999986
# solution={'a': [0, 1, 3]} probability=0.009 cost=5.8
# solution={'a': [1, 0, 2]} probability=0.006 cost=9.7
# solution={'a': [0, 1, 0]} probability=0.027 cost=10.899999999999999
# solution={'a': [1, 0, 3]} probability=0.004 cost=12.8
# solution={'a': [1, 0, 0]} probability=0.001 cost=20.9
# solution={'a': [0, 0, 2]} probability=0.013 cost=55.6
# solution={'a': [0, 0, 3]} probability=0.009 cost=56.1
# solution={'a': [0, 0, 1]} probability=0.005 cost=60.9
# solution={'a': [0, 0, 0]} probability=0.019 cost=72.0
# Text(0.5, 1.0, 'Optimization Progress')
